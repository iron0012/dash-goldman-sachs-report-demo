# %%
import plotly.plotly as py
from plotly.graph_objs import *
py.sign_in('alishobeiri', 'TGRyfPDCOfii9XmU7xU1')
trace1 = {
  "x": ["-0.007132542", "0.1225055975", "0.3863026902", "0.9079648204", "1.1653919822", "1.4244032874", "1.6919321285", "2.2076708305", "2.4645548693", "2.7264137009", "2.990876888", "3.2470699455", "3.5110061129", "3.7703892596", "4.0356182456", "4.5495005108", "5.0713983359", "5.3278446556", "5.5857432072", "5.8595643903", "6.1092982163", "6.3690327095", "6.6278595577", "6.890945174", "7.1476550035", "7.4065623686", "7.6640949344", "7.9254238185"], 
  "y": ["-160.5370311532", "-114.5058234561", "-214.7994168289", "23.2276325099", "-158.5585749201", "-20.2588782557", "-175.2184549557", "-96.5976704333", "-183.6102239891", "54.3180633104", "-162.2073697194", "-128.6453555431", "-253.207135218", "-179.7929050873", "66.5666832703", "-127.3838820684", "69.5149778533", "58.8833475007", "-205.1592387636", "-265.0871079957", "-297.4349777249", "-285.329849831", "-114.8428744923", "-90.9855358358", "-147.598992866", "8.8379798768", "-191.3409582243", "139.0618916156"], 
  "line": {"color": "rgb(92, 53, 143)"}, 
  "mode": "lines", 
  "name": "Energy share of HY Issuance", 
  "type": "scatter", 
  "uid": "203858", 
  "xsrc": "alishobeiri:643:6deeea", 
  "ysrc": "alishobeiri:643:bc5955"
}
trace2 = {
  "x": ["0.0117354652", "0.1280431899", "0.3947769848", "0.6580417856", "1.1674097761", "1.4270390621", "1.6869508719", "1.9364154723", "2.2064255465", "2.476566592", "2.7296667071", "2.9859046462", "3.2493022893", "3.5055739067", "3.7655530731", "4.015070062", "4.2918010864", "4.5482551281", "4.8045810051", "5.0746734041", "5.3139779964", "5.5907763775", "5.8471611915", "6.106736218", "6.3726402165", "6.6360004392", "7.4194948703", "7.682862577", "7.9360150807", "8.1854778101"], 
  "y": ["20.4538362802", "22.1459006116", "24.1205385831", "25.0222998674", "25.3552172036", "21.6479154728", "23.9402107702", "22.1596287469", "21.1147030487", "22.851047496", "25.6795284877", "22.5482459417", "26.2710098021", "23.8549110078", "27.5775738086", "26.9094998435", "23.4013655644", "24.8591787584", "23.5953204529", "24.2986217033", "24.5440904642", "22.4663236884", "22.4540369484", "17.5944947288", "1.9477997072", "4.8759149546", "18.9842042845", "22.0712492546", "26.0122383045", "24.1919238506"], 
  "line": {"color": "rgb(190, 177, 209)"}, 
  "mode": "lines", 
  "name": "US oil rig count  (monthly change)", 
  "type": "scatter", 
  "uid": "e17c2f", 
  "xsrc": "alishobeiri:643:a6f27a", 
  "yaxis": "y2", 
  "ysrc": "alishobeiri:643:2b0890"
}
data = Data([trace1, trace2])
layout = {
  "autosize": True, 
  "hovermode": "closest", 
  "legend": {
    "x": 0.0113541352753, 
    "y": -0.0332788206688, 
    "bgcolor": "rgba(255, 255, 255, 0)", 
    "font": {
      "color": "rgb(68, 68, 68)", 
      "size": 9
    }, 
    "orientation": "h", 
    "traceorder": "reversed"
  }, 
  "margin": {
    "r": 30, 
    "t": 10, 
    "b": 0, 
    "l": 30
  }, 
  "showlegend": True, 
  "xaxis": {
    "autorange": True, 
    "nticks": 10, 
    "range": [-0.007132542, 8.1854778101], 
    "showgrid": False, 
    "tickfont": {"size": 9}, 
    "ticks": "", 
    "ticktext": ["Jan-13", "May-13", "Sep-13", "Jan-14", "May-14", "Sep-14", "Jan-15", "May-15"], 
    "tickvals": [0, 1, 2, 3, 4, 5, 6, 7], 
    "title": "", 
    "type": "linear", 
    "zeroline": True, 
    "zerolinecolor": "rgb(136, 137, 140)"
  }, 
  "yaxis": {
    "autorange": False, 
    "linecolor": "rgb(136, 137, 140)", 
    "nticks": 10, 
    "range": [-300, 150], 
    "showgrid": False, 
    "showline": False, 
    "tickfont": {"size": 9}, 
    "ticks": "outside", 
    "title": "", 
    "type": "linear", 
    "zeroline": True, 
    "zerolinecolor": "rgb(136, 137, 140)"
  }, 
  "yaxis2": {
    "anchor": "x", 
    "autorange": False, 
    "linecolor": "rgb(136, 137, 140)", 
    "nticks": 8, 
    "overlaying": "y", 
    "range": [0, 35], 
    "showgrid": False, 
    "showline": True, 
    "side": "right", 
    "tickfont": {"size": 9}, 
    "ticks": "outside", 
    "ticksuffix": " %", 
    "type": "linear", 
    "zeroline": False, 
    "zerolinecolor": "rgb(136, 137, 140)"
  }
}
fig = Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~alishobeiri/644.embed" height="525px" width="100%"></iframe>
